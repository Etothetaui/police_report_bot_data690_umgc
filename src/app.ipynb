# %%
# police_report_bot/
# |
# ├── groq_api_key.txt
# │
# ├── src/
# |   ├── utils.py
# |   ├── pipeline.py
# │   ├── config.py
# │   ├── data_loader.py
# │   ├── scenario_generator.py
# │   ├── interview_bot.py
# │   ├── grader.py
# │   ├── session_logger.py
# │   ├── ui.py
# │   └── app.py
# │
# ├── source_docs/
# │   ├── checklists/            # original PDFs (already exists)
# │   ├── checklists_json/       # the 6 JSON files (already exists)
# │   ├── manuals/               # reference PDFs (already exists)
# │   └── legal_context/         # legal_context.txt (already exists)
# │
# ├── validation/
# │   └── scenarios_for_review.pdf   # already exists
# │
# └── sessions/                  # new — where completed session logs get saved

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install Java (required for LanguageTool)
# !apt-get install -y default-jre-headless -qq

# Install dependencies
# !pip install -r /content/drive/MyDrive/police_report_bot-1.0.0-alpha/requirements.txt --quiet

# %%
# Set path
import sys
sys.path.append('/content/drive/MyDrive/police_report_bot-1.0.0-alpha/src')

# %%
# Launch gradio
from ui import launch
launch()
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://82299823e21b229396.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://82299823e21b229396.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Downloading LanguageTool 6.8-SNAPSHOT:   2%|▏         | 4.54M/259M [00:01<00:35, 7.09MB/s]
#   Generating facts (38 elements)...
# Downloading LanguageTool 6.8-SNAPSHOT:  21%|██▏       | 55.6M/259M [00:05<00:18, 10.9MB/s]
#   Validating scenario...
# Downloading LanguageTool 6.8-SNAPSHOT: 100%|██████████| 259M/259M [00:21<00:00, 11.9MB/s]
# Session saved: /content/drive/MyDrive/police_report_bot-1.0.0-alpha/sessions/pov_20260504_081300_3483c965.json
# PDF saved: /content/drive/MyDrive/police_report_bot-1.0.0-alpha/sessions/pov_20260504_081300_3483c965.pdf
